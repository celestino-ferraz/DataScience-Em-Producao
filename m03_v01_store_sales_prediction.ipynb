# %% [markdown]
# # 0.0. IMPORTS

# %%
import math
import numpy as np
import pandas as pd
import inflection

import seaborn as sns

from matplotlib import pyplot as plt

import inflection
from IPython.core.display import HTML
from IPython.display import Image
import datetime

# %% [markdown]
# ## 0.1. Helper Functions

# %% [markdown]
# ## 0.2. Loading Data

# %%
df_sales_raw = pd.read_csv('data/train.csv', low_memory=False)
df_store_raw = pd.read_csv('data/store.csv', low_memory=False)

# merge
df_raw = pd.merge(df_sales_raw, df_store_raw, how='left', on='Store')

# %%
df_raw.sample(5)
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 890858    759          3  2013-04-24   6755        829     1      1
# 929000    991          4  2013-03-21   5444        528     1      1
# 33800     351          3  2015-07-01   6742        507     1      1
# 781808    979          3  2013-07-31   7961        688     1      1
# 720682     63          1  2013-09-23   6998        630     1      1
#
#        StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 890858            0              0         a          a                110.0
# 929000            0              0         a          a               1010.0
# 33800             0              1         a          a               5290.0
# 781808            0              1         a          c               2270.0
# 720682            0              0         c          c               3700.0
#
#         CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 890858                       11.0                    2012.0       1
# 929000                        NaN                       NaN       0
# 33800                        11.0                    2012.0       1
# 781808                       11.0                    2005.0       1
# 720682                        6.0                    2010.0       1
#
#         Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 890858             31.0           2013.0  Feb,May,Aug,Nov
# 929000              NaN              NaN              NaN
# 33800               5.0           2013.0  Feb,May,Aug,Nov
# 781808             14.0           2011.0  Jan,Apr,Jul,Oct
# 720682             18.0           2010.0  Feb,May,Aug,Nov

# %% [markdown]
# # 1.0. DATA DESCRIPTION

# %%
# copy original data
df1 = df_raw.copy()

# %% [markdown]
# ## 1.1. Rename Columns

# %%
cols_old = ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
           'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
           'CompetitionDistance', 'CompetitionOpenSinceMonth',
           'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
           'Promo2SinceYear', 'PromoInterval']

# Apply snakecase to columns names
snakecase = lambda x: inflection.underscore( x )
cols_new = list(map(snakecase, cols_old))

#rename
df1.columns = cols_new

# %% [markdown]
# ## 1.2. Data Dimensions

# %%
print('Number of Rows: {}'.format(df1.shape[0]))
print('Number of Cols: {}'.format(df1.shape[1]))
# Out:
# Number of Rows: 1017209
# Number of Cols: 18

# %% [markdown]
# ## 1.3. Data Types

# %%
df1['date'] = pd.to_datetime( df1['date'] )
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# ## 1.4. Check NA

# %%
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# ## 1.5. Fillout NA

# %%
df1.sample()
# Out:
#         store  day_of_week       date  sales  customers  open  promo  \
# 600975    776            4 2014-01-09   4956        564     1      1
#
#        state_holiday  school_holiday store_type assortment  \
# 600975             0               0          c          a
#
#         competition_distance  competition_open_since_month  \
# 600975                 700.0                           4.0
#
#         competition_open_since_year  promo2  promo2_since_week  \
# 600975                       2009.0       1               14.0
#
#         promo2_since_year   promo_interval
# 600975             2011.0  Jan,Apr,Jul,Oct

# %%
df1['competition_distance'].max()
# Out:
# 75860.0

# %%
#competition_distance
# market analysis assumption: position without values means a far competition distance, higher than the
# maximum value from the raw data.
df1['competition_distance'] = df1['competition_distance'].apply(lambda x: 200000.0 if math.isnan(x) else x)

# competition_open_since_month
# Assumption: for NA values apply the value from "date" column, because the competition does exist and it can affect
# over time the sales performance.
df1['competition_open_since_month'] = df1.apply(lambda x: x['date'].month if math.isnan(x['competition_open_since_month']) else x['competition_open_since_month'], axis=1)

#competition_open_since_year
# Same assumption as competition_open_since_month
df1['competition_open_since_year'] = df1.apply(lambda x: x['date'].year if math.isnan(x['competition_open_since_year']) else x['competition_open_since_year'], axis=1)

#promo2_since_week
# Assumptions: 1. NA values mean the store did not take place in promo2. 2. apply the value from "date" column.
df1['promo2_since_week'] = df1.apply(lambda x: x['date'].week if math.isnan(x['promo2_since_week']) else x['promo2_since_week'], axis=1)

#promo2_since_year
df1['promo2_since_year'] = df1.apply(lambda x: x['date'].year if math.isnan(x['promo2_since_year']) else x['promo2_since_year'], axis=1)

#promo_interval
# Dictionary for Months
month_map = {1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', 7:'Jul', 8:'Aug', 9:'Sep', 10:'Oct', 11:'Nov', 12:'Dec'}

# Fill NA values with zero.
df1['promo_interval'].fillna(0, inplace=True)

# Add new column with month information
df1['month_map'] = df1['date'].dt.month.map(month_map)

# New column that shows if at that date the store was in promo2.
df1['is_promo'] = df1[['promo_interval', 'month_map']].apply(lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval'].split(',') else 0, axis=1)

# %%
df1.isna().sum()
# Out:
# store                           0
# day_of_week                     0
# date                            0
# sales                           0
# customers                       0
# open                            0
# promo                           0
# state_holiday                   0
# school_holiday                  0
# store_type                      0
# assortment                      0
# competition_distance            0
# competition_open_since_month    0
# competition_open_since_year     0
# promo2                          0
# promo2_since_week               0
# promo2_since_year               0
# promo_interval                  0
# month_map                       0
# is_promo                        0
# dtype: int64

# %% [markdown]
# ## 1.6. Change Types

# %%
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# month_map                               object
# is_promo                                 int64
# dtype: object

# %%
df1['competition_open_since_month'] = df1['competition_open_since_month'].astype(int)
df1['competition_open_since_year'] = df1['competition_open_since_year'].astype(int)

df1['promo2_since_week'] = df1['promo2_since_week'].astype(int)
df1['promo2_since_year'] = df1['promo2_since_year'].astype(int)

# %%
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month             int64
# competition_open_since_year              int64
# promo2                                   int64
# promo2_since_week                        int64
# promo2_since_year                        int64
# promo_interval                          object
# month_map                               object
# is_promo                                 int64
# dtype: object

# %% [markdown]
# ## 1.7. Descriptive Statistical

# %%
num_attributes = df1.select_dtypes(include=['int64', 'float64'])
cat_attributes = df1.select_dtypes(exclude=['int64', 'float64', 'datetime64[ns]'])

# %% [markdown]
# ### 1.7.1 Numerical Attributes

# %%
#Central Tendency - mean, median
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

# Dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame(num_attributes.apply(np.std)).T
d2 = pd.DataFrame(num_attributes.apply(min)).T
d3 = pd.DataFrame(num_attributes.apply(max)).T
d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max()-x.min())).T
d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew())).T
d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T

# concatenate
m = pd.concat([d2, d3, d4, ct1, ct2, d1, d5, d6]).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']
m
# Out:
#                       attributes     min       max     range         mean  \
# 0                          store     1.0    1115.0    1114.0   558.429727
# 1                    day_of_week     1.0       7.0       6.0     3.998341
# 2                          sales     0.0   41551.0   41551.0  5773.818972
# 3                      customers     0.0    7388.0    7388.0   633.145946
# 4                           open     0.0       1.0       1.0     0.830107
# 5                          promo     0.0       1.0       1.0     0.381515
# 6                 school_holiday     0.0       1.0       1.0     0.178647
# 7           competition_distance    20.0  200000.0  199980.0  5935.442677
# 8   competition_open_since_month     1.0      12.0      11.0     6.786849
# 9    competition_open_since_year  1900.0    2015.0     115.0  2010.324840
# 10                        promo2     0.0       1.0       1.0     0.500564
# 11             promo2_since_week     1.0      52.0      51.0    23.619033
# 12             promo2_since_year  2009.0    2015.0       6.0  2012.793297
# 13                      is_promo     0.0       1.0       1.0     0.165966
#
#     median           std       skew    kurtosis
# 0    558.0    321.908493  -0.000955   -1.200524
# 1      4.0      1.997390   0.001593   -1.246873
# 2   5744.0   3849.924283   0.641460    1.778375
# 3    609.0    464.411506   1.598650    7.091773
# 4      1.0      0.375539  -1.758045    1.090723
# 5      0.0      0.485758   0.487838   -1.762018
# 6      0.0      0.383056   1.677842    0.815154
# 7   2330.0  12547.646829  10.242344  147.789712
# 8      7.0      3.311085  -0.042076   -1.232607
# 9   2012.0      5.515591  -7.235657  124.071304
# 10     1.0      0.500000  -0.002255   -1.999999
# 11    22.0     14.310057   0.178723   -1.184046
# 12  2013.0      1.662657  -0.784436   -0.210075
# 13     0.0      0.372050   1.795644    1.224338

# %%
sns.distplot(df1['competition_distance'])
sns.displot(df1['competition_distance'])
sns.histplot(df1['competition_distance'])
# Out:
# /tmp/ipykernel_1903/2350956058.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['competition_distance'])
# <Axes: xlabel='competition_distance', ylabel='Count'>

# %% [markdown]
# ### 1.7.2 Categorical Attributes

# %%
cat_attributes.apply(lambda x: x.unique().shape[0])
# Out:
# state_holiday      4
# store_type         4
# assortment         3
# promo_interval     4
# month_map         12
# dtype: int64

# %%
aux1 = df1[(df1['state_holiday'] != '0') &  (df1['sales'] > 0)]
# plt.subplot(1, 3, 1)
sns.boxplot(x='state_holiday', y='sales', data=aux1)
# Out:
# <Axes: xlabel='state_holiday', ylabel='sales'>

# %%
# plt.subplot(1, 3, 2)
sns.boxplot(x='store_type', y='sales', data=aux1)
# Out:
# <Axes: xlabel='store_type', ylabel='sales'>

# %%
# plt.subplot(1, 3, 3)
sns.boxplot(x='assortment', y='sales', data=aux1)
# Out:
# <Axes: xlabel='assortment', ylabel='sales'>

# %% [markdown]
# # 2.0. Feature Engineering

# %%
Image('img/Mindmaphypothesis.png')

# %% [markdown]
# ## 2.1. Criacao de Hipteses

# %% [markdown]
# ## 2.1.1 Hipoteses Loja

# %% [markdown]
# **1.** Lojas com maior quadro de funcionarios deveriam vender mais.
#
# **2.** Lojas com maior estoque deveriam vender mais.
#
# **3.** Lojas com maior porte deveriam vender mais.
#
# **4.** Lojas com maior sortimento deveriam vender mais.
#
# **5.** Lojas com competidores mais proximos deveriam vender menos.
#
# **6.** Lojas com competidores à mais tempo deveriam vender mais.

# %% [markdown]
# ## 2.1.2 Hipoteses Produto

# %% [markdown]
# **1.** Lojas que investem mais em Marketion deveriam vender mais.
#
# **2.** Lojas que expoem mais o produto deveriam vender mais.
#
# **3.** Lojas com precos menores deveriam vender mais.
#
# **4.** Lojas com precos menores por mais tempo deveriam vender mais.
#
# **5.** Lojas com promocoes agressivas(descontos maiores) deveriam vender mais.
#
# **6.** Lojas com mais dias de promocao deveriam vender mais.
#
# **7.** Lojas com mais promocoes consecutivas deveriam vender mais.

# %% [markdown]
# ## 2.1.3 Hipoteses Tempo

# %% [markdown]
# **1.** Lojas abertaas durante o feriado de Natal deveriam vender mais.
#
# **2.** Lojas deveriam vender mais ao longo dos anos (Store age ).
#
# **3.** Lojas deveriam vender mais no segundo semestre do ano.
#
# **4.** Lojas deveriam vender mais depois do dia 10 de cada mes.
#
# **5.** Lojas deveriam vender menos aos fins de semana.
#
# **6.** Lojas deveriam vender menos durante os feriados escolares.

# %% [markdown]
# ## 2.2. Lista Final de Hipoteses

# %% [markdown]
# **1.** Lojas com maior sortimento deveriam vender mais.
#
# **2.** Lojas com competidores mais proximos deveriam vender menos.
#
# **3.** Lojas com competidores à mais tempo deveriam vender mais.
#
# **4.** Lojas com promocoes agressivas(descontos maiores) deveriam vender mais.
#
# **5.** Lojas com mais dias de promocao deveriam vender mais.
#
# **6.** Lojas com mais promocoes consecutivas deveriam vender mais.
#
# **7.** Lojas abertaas durante o feriado de Natal deveriam vender mais.
#
# **8.** Lojas deveriam vender mais ao longo dos anos (Store age ).
#
# **9.** Lojas deveriam vender mais no segundo semestre do ano.
#
# **10.** Lojas deveriam vender mais depois do dia 10 de cada mes.
#
# **11.** Lojas deveriam vender menos aos fins de semana.
#
# **12.** Lojas deveriam vender menos durante os feriados escolares.

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.3. Feature Engineering

# %%
# year
df2['year'] = df2['date'].dt.year
# month
df2['month'] = df2['date'].dt.month
# day
df2['day'] = df2['date'].dt.day
# week of the year
# df2['week_of_year'] = df2['date'].dt.weekofyear
df2['week_of_year'] = df2['date'].dt.isocalendar().week
# year week
df2['year_week'] = df2['date'].dt.strftime('%Y-%W')

# competition since
df2['competition_since'] = df2.apply( lambda x: datetime.datetime(year=x['competition_open_since_year'], month=x['competition_open_since_month'], day=1 ), axis=1 )
df2['competition_time_month']= ((df2['date'] - df2['competition_since'])/30).apply(lambda x: x.days).astype(int)

# promo since
df2['promo_since'] = df2['promo2_since_year'].astype(str)+'-'+df2['promo2_since_week'].astype(str)
df2['promo_since'] = df2['promo_since'].apply( lambda x: datetime.datetime.strptime( x + '-1', '%Y-%W-%w' ) - datetime.timedelta(days=7))
df2['promo_time_week'] = ((df2['date'] - df2['promo_since'])/ 7).apply(lambda x: x.days).astype(int)
                                              
# assortment
df2['assortment'] = df2['assortment'].apply(lambda x : 'basic' if x == 'a' else 'extra' if x == 'b' else 'extended' )
# stateholiday
df2['state_holiday'] = df2['state_holiday'].apply(lambda x : 'public_holiday' if x == 'a' else 'easter_holiday' if x == 'b' else 'christmas' if x == 'c' else 'regular_day')

# %%
df2.sample(20).T
# Out:
#                                           558013               449107   \
# store                                         184                  548
# day_of_week                                     7                    7
# date                          2014-02-16 00:00:00  2014-05-25 00:00:00
# sales                                           0                    0
# customers                                       0                    0
# open                                            0                    0
# promo                                           0                    0
# state_holiday                         regular_day          regular_day
# school_holiday                                  0                    0
# store_type                                      d                    d
# assortment                               extended             extended
# competition_distance                       3560.0               3760.0
# competition_open_since_month                    2                    2
# competition_open_since_year                  2014                 2009
# promo2                                          0                    0
# promo2_since_week                               7                   21
# promo2_since_year                            2014                 2014
# promo_interval                                  0                    0
# month_map                                     Feb                  May
# is_promo                                        0                    0
# year                                         2014                 2014
# month                                           2                    5
# day                                            16                   25
# week_of_year                                    7                   21
# year_week                                 2014-06              2014-20
# competition_since             2014-02-01 00:00:00  2009-02-01 00:00:00
# competition_time_month                          0                   64
# promo_since                   2014-02-10 00:00:00  2014-05-19 00:00:00
# promo_time_week                                 0                    0
#
#                                           190043               939428   \
# store                                         494                  269
# day_of_week                                     3                    1
# date                          2015-02-11 00:00:00  2013-03-11 00:00:00
# sales                                        6329                 9472
# customers                                    1020                 1171
# open                                            1                    1
# promo                                           0                    0
# state_holiday                         regular_day          regular_day
# school_holiday                                  0                    0
# store_type                                      b                    a
# assortment                                  basic             extended
# competition_distance                       1260.0                 60.0
# competition_open_since_month                    6                    6
# competition_open_since_year                  2011                 2015
# promo2                                          0                    0
# promo2_since_week                               7                   11
# promo2_since_year                            2015                 2013
# promo_interval                                  0                    0
# month_map                                     Feb                  Mar
# is_promo                                        0                    0
# year                                         2015                 2013
# month                                           2                    3
# day                                            11                   11
# week_of_year                                    7                   11
# year_week                                 2015-06              2013-10
# competition_since             2011-06-01 00:00:00  2015-06-01 00:00:00
# competition_time_month                         45                  -28
# promo_since                   2015-02-09 00:00:00  2013-03-11 00:00:00
# promo_time_week                                 0                    0
#
#                                           394846               211615   \
# store                                         538                  881
# day_of_week                                     2                    5
# date                          2014-07-15 00:00:00  2015-01-23 00:00:00
# sales                                        4300                 3019
# customers                                     625                  510
# open                                            1                    1
# promo                                           1                    0
# state_holiday                         regular_day          regular_day
# school_holiday                                  1                    0
# store_type                                      a                    a
# assortment                                  basic                basic
# competition_distance                        990.0                180.0
# competition_open_since_month                    2                    3
# competition_open_since_year                  2010                 2008
# promo2                                          0                    1
# promo2_since_week                              29                   31
# promo2_since_year                            2014                 2013
# promo_interval                                  0      Feb,May,Aug,Nov
# month_map                                     Jul                  Jan
# is_promo                                        0                    0
# year                                         2014                 2015
# month                                           7                    1
# day                                            15                   23
# week_of_year                                   29                    4
# year_week                                 2014-28              2015-03
# competition_since             2010-02-01 00:00:00  2008-03-01 00:00:00
# competition_time_month                         54                   83
# promo_since                   2014-07-14 00:00:00  2013-07-29 00:00:00
# promo_time_week                                 0                   77
#
#                                           899659               72201    \
# store                                         640                  842
# day_of_week                                     2                    4
# date                          2013-04-16 00:00:00  2015-05-28 00:00:00
# sales                                        8133                16288
# customers                                     717                  956
# open                                            1                    1
# promo                                           0                    0
# state_holiday                         regular_day          regular_day
# school_holiday                                  0                    1
# store_type                                      d                    d
# assortment                               extended             extended
# competition_distance                       8040.0               1200.0
# competition_open_since_month                    4                   11
# competition_open_since_year                  2013                 2007
# promo2                                          0                    0
# promo2_since_week                              16                   22
# promo2_since_year                            2013                 2015
# promo_interval                                  0                    0
# month_map                                     Apr                  May
# is_promo                                        0                    0
# year                                         2013                 2015
# month                                           4                    5
# day                                            16                   28
# week_of_year                                   16                   22
# year_week                                 2013-15              2015-21
# competition_since             2013-04-01 00:00:00  2007-11-01 00:00:00
# competition_time_month                          0                   92
# promo_since                   2013-04-15 00:00:00  2015-05-25 00:00:00
# promo_time_week                                 0                    0
#
#                                           241035               738127   \
# store                                        1090                  783
# day_of_week                                     6                    7
# date                          2014-12-27 00:00:00  2013-09-08 00:00:00
# sales                                        3975                    0
# customers                                     462                    0
# open                                            1                    0
# promo                                           0                    0
# state_holiday                         regular_day          regular_day
# school_holiday                                  0                    0
# store_type                                      a                    d
# assortment                                  basic             extended
# competition_distance                        330.0              15490.0
# competition_open_since_month                   12                    9
# competition_open_since_year                  2014                 2013
# promo2                                          1                    0
# promo2_since_week                              14                   36
# promo2_since_year                            2011                 2013
# promo_interval                    Jan,Apr,Jul,Oct                    0
# month_map                                     Dec                  Sep
# is_promo                                        0                    0
# year                                         2014                 2013
# month                                          12                    9
# day                                            27                    8
# week_of_year                                   52                   36
# year_week                                 2014-51              2013-35
# competition_since             2014-12-01 00:00:00  2013-09-01 00:00:00
# competition_time_month                          0                    0
# promo_since                   2011-03-28 00:00:00  2013-09-02 00:00:00
# promo_time_week                               195                    0
#
#                                           766039               288167   \
# store                                         820                  435
# day_of_week                                     3                    4
# date                          2013-08-14 00:00:00  2014-11-06 00:00:00
# sales                                       14127                 3225
# customers                                    1277                  400
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  1                    0
# store_type                                      a                    a
# assortment                               extended                basic
# competition_distance                       1650.0                910.0
# competition_open_since_month                    8                   11
# competition_open_since_year                  2013                 2014
# promo2                                          1                    0
# promo2_since_week                              40                   45
# promo2_since_year                            2014                 2014
# promo_interval                    Jan,Apr,Jul,Oct                    0
# month_map                                     Aug                  Nov
# is_promo                                        0                    0
# year                                         2013                 2014
# month                                           8                   11
# day                                            14                    6
# week_of_year                                   33                   45
# year_week                                 2013-32              2014-44
# competition_since             2013-08-01 00:00:00  2014-11-01 00:00:00
# competition_time_month                          0                    0
# promo_since                   2014-09-29 00:00:00  2014-11-03 00:00:00
# promo_time_week                               -59                    0
#
#                                           265626               674315   \
# store                                         319                  526
# day_of_week                                     7                    1
# date                          2014-11-30 00:00:00  2013-11-04 00:00:00
# sales                                           0                16588
# customers                                       0                 1956
# open                                            0                    1
# promo                                           0                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  0                    0
# store_type                                      a                    a
# assortment                               extended                basic
# competition_distance                        570.0                120.0
# competition_open_since_month                    9                   11
# competition_open_since_year                  2012                 2013
# promo2                                          1                    1
# promo2_since_week                              27                   48
# promo2_since_year                            2012                 2011
# promo_interval                   Mar,Jun,Sept,Dec     Mar,Jun,Sept,Dec
# month_map                                     Nov                  Nov
# is_promo                                        0                    0
# year                                         2014                 2013
# month                                          11                   11
# day                                            30                    4
# week_of_year                                   48                   45
# year_week                                 2014-47              2013-44
# competition_since             2012-09-01 00:00:00  2013-11-01 00:00:00
# competition_time_month                         27                    0
# promo_since                   2012-06-25 00:00:00  2011-11-21 00:00:00
# promo_time_week                               126                  102
#
#                                           748203               1007079  \
# store                                         824                 1020
# day_of_week                                     5                    4
# date                          2013-08-30 00:00:00  2013-01-10 00:00:00
# sales                                        8059                 8130
# customers                                    1098                 1037
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  0                    1
# store_type                                      a                    a
# assortment                                  basic                basic
# competition_distance                      17570.0                 40.0
# competition_open_since_month                    8                    8
# competition_open_since_year                  2013                 2015
# promo2                                          0                    0
# promo2_since_week                              35                    2
# promo2_since_year                            2013                 2013
# promo_interval                                  0                    0
# month_map                                     Aug                  Jan
# is_promo                                        0                    0
# year                                         2013                 2013
# month                                           8                    1
# day                                            30                   10
# week_of_year                                   35                    2
# year_week                                 2013-34              2013-01
# competition_since             2013-08-01 00:00:00  2015-08-01 00:00:00
# competition_time_month                          0                  -32
# promo_since                   2013-08-26 00:00:00  2013-01-07 00:00:00
# promo_time_week                                 0                    0
#
#                                           442682               297126   \
# store                                         813                 1081
# day_of_week                                     6                    2
# date                          2014-05-31 00:00:00  2014-10-28 00:00:00
# sales                                        4793                 6787
# customers                                     530                 1118
# open                                            1                    1
# promo                                           0                    0
# state_holiday                         regular_day          regular_day
# school_holiday                                  0                    1
# store_type                                      a                    b
# assortment                                  basic                basic
# competition_distance                       1560.0                400.0
# competition_open_since_month                    9                    3
# competition_open_since_year                  2003                 2006
# promo2                                          0                    0
# promo2_since_week                              22                   44
# promo2_since_year                            2014                 2014
# promo_interval                                  0                    0
# month_map                                     May                  Oct
# is_promo                                        0                    0
# year                                         2014                 2014
# month                                           5                   10
# day                                            31                   28
# week_of_year                                   22                   44
# year_week                                 2014-21              2014-43
# competition_since             2003-09-01 00:00:00  2006-03-01 00:00:00
# competition_time_month                        130                  105
# promo_since                   2014-05-26 00:00:00  2014-10-27 00:00:00
# promo_time_week                                 0                    0
#
#                                           1000844              941177
# store                                         360                  903
# day_of_week                                     2                    7
# date                          2013-01-15 00:00:00  2013-03-10 00:00:00
# sales                                        5888                    0
# customers                                     694                    0
# open                                            1                    0
# promo                                           0                    0
# state_holiday                         regular_day          regular_day
# school_holiday                                  0                    0
# store_type                                      a                    d
# assortment                                  basic             extended
# competition_distance                       2040.0               7290.0
# competition_open_since_month                    6                    9
# competition_open_since_year                  2007                 2014
# promo2                                          0                    0
# promo2_since_week                               3                   10
# promo2_since_year                            2013                 2013
# promo_interval                                  0                    0
# month_map                                     Jan                  Mar
# is_promo                                        0                    0
# year                                         2013                 2013
# month                                           1                    3
# day                                            15                   10
# week_of_year                                    3                   10
# year_week                                 2013-02              2013-09
# competition_since             2007-06-01 00:00:00  2014-09-01 00:00:00
# competition_time_month                         68                  -18
# promo_since                   2013-01-14 00:00:00  2013-03-04 00:00:00
# promo_time_week                                 0                    0

# %% [markdown]
# # 3.0. Passo 03 - Filtragem de Variaveis

# %%
df3 = df2.copy()
df3.columns
# Out:
# Index(['store', 'day_of_week', 'date', 'sales', 'customers', 'open', 'promo',
#        'state_holiday', 'school_holiday', 'store_type', 'assortment',
#        'competition_distance', 'competition_open_since_month',
#        'competition_open_since_year', 'promo2', 'promo2_since_week',
#        'promo2_since_year', 'promo_interval', 'month_map', 'is_promo', 'year',
#        'month', 'day', 'week_of_year', 'year_week', 'competition_since',
#        'competition_time_month', 'promo_since', 'promo_time_week'],
#       dtype='object')

# %%
df3.sample(5)
# Out:
#         store  day_of_week       date  sales  customers  open  promo  \
# 678845    596            4 2013-10-31   4881        750     1      0
# 512120      6            6 2014-03-29   2968        337     1      0
# 82070     676            2 2015-05-19   9808       2059     1      1
# 679962    598            3 2013-10-30   5152        716     1      0
# 817138    629            6 2013-06-29   8834        801     1      0
#
#        state_holiday  school_holiday store_type  ... is_promo  year  month  \
# 678845   regular_day               0          c  ...        0  2013     10
# 512120   regular_day               0          a  ...        0  2014      3
# 82070    regular_day               0          b  ...        0  2015      5
# 679962   regular_day               1          c  ...        1  2013     10
# 817138   regular_day               0          d  ...        1  2013      6
#
#         day  week_of_year  year_week  competition_since  \
# 678845   31            44    2013-43         2006-09-01
# 512120   29            13    2014-12         2013-12-01
# 82070    19            21    2015-20         2008-09-01
# 679962   30            44    2013-43         2013-12-01
# 817138   29            26    2013-25         2014-07-01
#
#        competition_time_month promo_since  promo_time_week
# 678845                     87  2013-10-28                0
# 512120                      3  2014-03-24                0
# 82070                      81  2015-05-18                0
# 679962                     -2  2014-09-29              -48
# 817138                    -13  2015-06-01             -101
#
# [5 rows x 29 columns]

# %% [markdown]
# ## 3.1. Filtragem das linhas

# %%
df3 = df3[(df3['open'] != 0) & (df3['sales'] > 0)]

# %% [markdown]
# ## 3.2. Selecao das Colunas

# %%
cols_drop = ['customers', 'open', 'promo_interval', 'month_map']
df3 = df3.drop(cols_drop, axis = 1)

# %%
df3.sample(5)
# Out:
#         store  day_of_week       date  sales  promo state_holiday  \
# 659050    871            1 2013-11-18   7116      1   regular_day
# 20774     705            1 2015-07-13  12427      1   regular_day
# 225592    363            6 2015-01-10   6142      0   regular_day
# 312591    568            6 2014-10-11   5938      0   regular_day
# 335888    473            2 2014-09-16   3767      1   regular_day
#
#         school_holiday store_type assortment  competition_distance  ...  \
# 659050               0          d   extended               10620.0  ...
# 20774                1          a      basic                4140.0  ...
# 225592               0          a      basic                 250.0  ...
# 312591               0          d   extended                4270.0  ...
# 335888               0          a      basic                  50.0  ...
#
#         is_promo  year  month  day  week_of_year  year_week  \
# 659050         0  2013     11   18            47    2013-46
# 20774          0  2015      7   13            29    2015-28
# 225592         0  2015      1   10             2    2015-01
# 312591         1  2014     10   11            41    2014-40
# 335888         0  2014      9   16            38    2014-37
#
#         competition_since  competition_time_month  promo_since  \
# 659050         2013-11-01                       0   2013-11-18
# 20774          2012-09-01                      34   2011-04-25
# 225592         2009-09-01                      65   2015-01-05
# 312591         2014-10-01                       0   2012-12-31
# 335888         2014-09-01                       0   2014-09-15
#
#         promo_time_week
# 659050                0
# 20774               220
# 225592                0
# 312591               92
# 335888                0
#
# [5 rows x 25 columns]

# %%
df3.columns
# Out:
# Index(['store', 'day_of_week', 'date', 'sales', 'promo', 'state_holiday',
#        'school_holiday', 'store_type', 'assortment', 'competition_distance',
#        'competition_open_since_month', 'competition_open_since_year', 'promo2',
#        'promo2_since_week', 'promo2_since_year', 'is_promo', 'year', 'month',
#        'day', 'week_of_year', 'year_week', 'competition_since',
#        'competition_time_month', 'promo_since', 'promo_time_week'],
#       dtype='object')
